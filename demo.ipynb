# %%
# print ("Hello World");
 
# a = 10;
# if a>5 : 
#     print ("yes");

# def pattern( int r, int c):
#     print("**")

# pattern(4,5);

#installing mediapipe and open-cv library
# ! pip install mediapipe
! pip install opencv-python   

# mediapipe is an opensource frameword by Google 
# we will be using Hand landmark detection model 
# so will install it

# %%
import cv2
#we are capturing image for every second and passed it in while loop so it will act like a video
cap=cv2.VideoCapture(0)
while True:
    rec,frame=cap.read()
    cv2.imshow('Air Canvas',frame)
    cv2.waitKey(1)

# %%
# part 2 capture window and track landmarks and draw connectivites btwn landmarks
import cv2
import mediapipe as mp
import numpy as np 
mphand=mp.solutions.hands
hands=mphand.Hands()

mpDraw=mp.solutions.drawing_utils

cap=cv2.VideoCapture(0)

while True:
        ret, frame = cap.read()
        x, y, c = frame.shape

        # Image ko RGB format mein convert karna
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Hand landmarks ko detect karna
        results = hands.process(frame_rgb)

        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Haath ke landmarks ko draw karna
                for idx, landmark in enumerate(hand_landmarks.landmark):
                    cx, cy = int(landmark.x * frame.shape[1]), int(landmark.y * frame.shape[0])
                    cv2.circle(frame, (cx, cy), 5, (255, 0, 0), -1)

                # Landmarks ko connect karne ke liye
                mp_drawing = mp.solutions.drawing_utils
                mp_drawing.draw_landmarks(frame, hand_landmarks, mphand.HAND_CONNECTIONS)

        # Frame ko display karna
        cv2.imshow('Hand Landmarks', frame)

        # 'q' press karke loop se bahar nikalna
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Resources release karna
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import numpy as np 
mphand=mp.solutions.hands
hand=mphand.Hands()    #made object

mpDraw=mp.solutions.drawing_utils # lines between landmarks

cap=cv2.VideoCapture(0)  # 0 is used for default webcam of operating system

while True:
    success,img=cap.read()  # success is a boolean value

    imgrgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)    # converted BGR images to RGB because mediapipe only processes RGB images
    result=hand.process(imgrgb)     # only detects hands by a function of hand class i.e.process
    # print(result.multi_hand_landmarks)
    if result.multi_hand_landmarks:    # agr image me hand dikh rha hai toh loop execute hoga
        for handlm in result.multi_hand_landmarks:
                   
            for id,lm in enumerate(handlm.landmark):
                #print(id,lm) 
                h,w,c=img.shape    #height,width,channel
                cx,cy=int(lm.x*w),int(lm.y*h)    # turned relative position coordinates into absolute coordinates
                print(id,cx,cy)

            mpDraw.draw_landmarks(img,handlm,mphand.HAND_CONNECTIONS)  # agr yeh nhi hota toh image me points or lines dikhte mtlb draw nhi hote sirf coordiantes print hote, haath ke andar wali lines ki hi baat hi rhi hai
    cv2.imshow("Video",img)
    cv2.waitKey(1)   # 1 means in every 1 milisecond it will recapture

# %%
import numpy as np
np.zeros((3,4,5))

# %%
#part 1 to create paintwindow
import cv2
import numpy as np
import mediapipe as mp
from collections import deque

# Here is code for Canvas setup
paintWindow = np.zeros((471, 636, 3)) + 255       #3D matrix will be created with  3 columns , 636 rows,471 matrices
paintWindow = cv2.rectangle(paintWindow, (40, 1), (140, 65), (0, 0, 0), 2) #black  0,0,0 means black color
paintWindow = cv2.rectangle(paintWindow, (160, 1), (255, 65), (255, 0, 0), 2)#blue
paintWindow = cv2.rectangle(paintWindow, (275, 1), (370, 65), (0, 255, 0), 2)# Green
paintWindow = cv2.rectangle(paintWindow, (390, 1), (485, 65), (0, 0, 255), 2) #red
paintWindow = cv2.rectangle(paintWindow, (505, 1), (600, 65), (0, 255, 255), 2)#Yellow


cv2.rectangle(paintWindow, (160, 1), (255, 65), (255, 0, 0), -1)  # blue   filling color
cv2.rectangle(paintWindow, (275, 1), (370, 65), (0, 255, 0), -1)  # Green
cv2.rectangle(paintWindow, (390, 1), (485, 65), (0, 0, 255), -1)  #red
cv2.rectangle(paintWindow, (505, 1), (600, 65), (0, 255, 255), -1)  # Yellow

cv2.putText(paintWindow, "CLEAR", (49, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
cv2.putText(paintWindow, "BLUE", (185, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
cv2.putText(paintWindow, "GREEN", (298, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
cv2.putText(paintWindow, "RED", (420, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
cv2.putText(paintWindow, "YELLOW", (520, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

cv2.imshow("Paint", paintWindow)

cv2.waitKey(1)

# %%
#part 3 draw color panels on webcam window
import cv2
import mediapipe as mp
import numpy as np 
mphand=mp.solutions.hands
hands=mphand.Hands()

mpDraw=mp.solutions.drawing_utils

cap=cv2.VideoCapture(0)

while True:      # frame hum while loop me capture kar rhe the isliye frame ke upar kuch draw bhi karna higa toh while loop me hi karenge na
        ret, frame = cap.read()
        x, y, c = frame.shape

        
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # insert color panel
        frame = cv2.rectangle(frame, (40, 1), (140, 65), (0, 0, 0), 2)
        frame = cv2.rectangle(frame, (160, 1), (255, 65), (255, 0, 0), 2)
        frame = cv2.rectangle(frame, (275, 1), (370, 65), (0, 255, 0), 2)
        frame = cv2.rectangle(frame, (390, 1), (485, 65), (0, 0, 255), 2) 
        frame = cv2.rectangle(frame, (505, 1), (600, 65), (0, 255, 255), 2)
        cv2.putText(frame, "CLEAR", (49, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(frame, "BLUE", (185, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(frame, "GREEN", (298, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(frame, "RED", (420, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(frame, "YELLOW", (520, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)

        
        results = hands.process(frame_rgb)

        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                
                for idx, landmark in enumerate(hand_landmarks.landmark):
                    cx, cy = int(landmark.x * frame.shape[1]), int(landmark.y * frame.shape[0])
                    if idx==4 or idx==8:
                        cv2.circle(frame, (cx, cy), 15, (255, 255, 0), -1)

                
                mp_drawing = mp.solutions.drawing_utils
                mp_drawing.draw_landmarks(frame, hand_landmarks, mphand.HAND_CONNECTIONS)

        
        cv2.imshow('Hand Landmarks', frame)

        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    
cap.release()
cv2.destroyAllWindows()

# %%
# part 4  the logic inserting the tracked points in deques , and selection of color (in this logic we have 
# not drawn the points into window)
import cv2
import mediapipe as mp
import numpy as np
from collections import deque

# Initialize deques and indices for - blue,green,red,yellow colors
bpoints = [deque(maxlen=1024)]    #list 
gpoints = [deque(maxlen=1024)]
rpoints = [deque(maxlen=1024)]
ypoints = [deque(maxlen=1024)]

# These indices will be used to mark the points in particular deque of the specified color
blue_index = 0
green_index = 0
red_index = 0
yellow_index = 0

# to choose the colors we need colors list in BGR formate
colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (0, 255, 255)]  #0-blue,1-green,2-red,3-yellow
colorIndex = 0



mphand=mp.solutions.hands
hands=mphand.Hands()

mpDraw=mp.solutions.drawing_utils

cap=cv2.VideoCapture(0)

while True:
        ret, frame = cap.read()
        x, y, c = frame.shape

        

        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        frame = cv2.rectangle(frame, (40, 1), (140, 65), (0, 0, 0), 2)
        frame = cv2.rectangle(frame, (160, 1), (255, 65), (255, 0, 0), 2)
        frame = cv2.rectangle(frame, (275, 1), (370, 65), (0, 255, 0), 2)
        frame = cv2.rectangle(frame, (390, 1), (485, 65), (0, 0, 255), 2) 
        frame = cv2.rectangle(frame, (505, 1), (600, 65), (0, 255, 255), 2)
        cv2.putText(frame, "CLEAR", (49, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(frame, "BLUE", (185, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(frame, "GREEN", (298, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(frame, "RED", (420, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(frame, "YELLOW", (520, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)

        
        results = hands.process(frame_rgb)

        if results.multi_hand_landmarks:   # hand detect ho rha agar
            landmarks = []
            for hand_landmarks in results.multi_hand_landmarks:
               
                for idx, landmark in enumerate(hand_landmarks.landmark):
                    cx, cy = int(landmark.x * frame.shape[1]), int(landmark.y * frame.shape[0])
                    
                    landmarks.append([cx, cy])
                
                mp_drawing = mp.solutions.drawing_utils
                mp_drawing.draw_landmarks(frame, hand_landmarks, mphand.HAND_CONNECTIONS)
            fore_finger = (landmarks[8][0], landmarks[8][1])# Extracts the coordinates of the index finger landmark.
            center = fore_finger # Assigns the extracted index finger coordinates to the variable 'center'.
            thumb = (landmarks[4][0], landmarks[4][1]) # Extracts the coordinates of the thumb landmark.
            cv2.circle(frame, center, 3  , (0, 255, 0), -1)# Draws a filled circle representing the index finger on the frame.
            


            # if thumb and fore_finger is  joined
            if (thumb[1] - center[1] < 30):   # mtlb joined hain dono fingers
                bpoints.append(deque(maxlen=512))
                blue_index += 1
                gpoints.append(deque(maxlen=512))
                green_index += 1
                rpoints.append(deque(maxlen=512))
                red_index += 1
                ypoints.append(deque(maxlen=512))
                yellow_index += 1
                
            #when center is in color panel 
            elif center[1] <= 65:
                if 40 <= center[0] <= 140:  # Clear Button
                    bpoints = [deque(maxlen=512)]
                    gpoints = [deque(maxlen=512)]
                    rpoints = [deque(maxlen=512)]
                    ypoints = [deque(maxlen=512)]

                    blue_index = 0
                    green_index = 0
                    red_index = 0
                    yellow_index = 0

                    paintWindow[ 67 :, :, : ] = 255     #buttons wala part bhi white na ho jaye isliye 67 ya 65 slicing kiye hain aur baaki saare pixels white ho jayenge
                elif 160 <= center[0] <= 255:
                    colorIndex = 0  # Blue
                elif 275 <= center[0] <= 370:
                    colorIndex = 1  # Green
                elif 390 <= center[0] <= 485:
                    colorIndex = 2  # Red
                elif 505 <= center[0] <= 600:
                    colorIndex = 3  # Yellow
            #when  we are drawing ,insert the tracked point into deque
            else:
                if colorIndex == 0:
                    bpoints[blue_index].appendleft(center)
                elif colorIndex == 1:
                    gpoints[green_index].appendleft(center)
                elif colorIndex == 2:
                    rpoints[red_index].appendleft(center)
                elif colorIndex == 3:
                    ypoints[yellow_index].appendleft(center)
    # Append the next deques when nothing is detected to avoid messing up
        else:                                   # agr hand hi detect nhi ho rha
            bpoints.append(deque(maxlen=512))
            blue_index += 1
            gpoints.append(deque(maxlen=512))
            green_index += 1
            rpoints.append(deque(maxlen=512))
            red_index += 1
            ypoints.append(deque(maxlen=512))
            yellow_index += 1
        
        
        cv2.imshow('Hand Landmarks', frame)

        
        if cv2.waitKey(1) & 0xFF == ord('q'):    # agr 'q' press kar denge toh stop ho jayega captue karna 
            break

    
cap.release()
cv2.destroyAllWindows()

# %%
#part 5 our air canva is ready now we can draw in canva

# Import necessary frameworks
import cv2  #open cv library for computer vision tasks
import numpy as np
import mediapipe as mp  #Framework for building multimodal (e.g., video, audio) ML applications.
from collections import deque

# Initialize deques and indices for - blue,green,red,yellow colors
bpoints = [deque(maxlen=1024)]                   # [] - means list
gpoints = [deque(maxlen=1024)]
rpoints = [deque(maxlen=1024)]
ypoints = [deque(maxlen=1024)]

# These indices will be used to mark the points in particular deque of the specified color
blue_index = 0
green_index = 0
red_index = 0
yellow_index = 0


#BGR format
colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (0, 255, 255)]
colorIndex = 0

# Here is code for Canvas setup       
# sabme 255 nhar diya toh saare pixels white ho gaye
paintWindow = np.zeros((471, 636, 3)) + 255
paintWindow = cv2.rectangle(paintWindow, (40, 1), (140, 65), (0, 0, 0), 2)
paintWindow = cv2.rectangle(paintWindow, (160, 1), (255, 65), (255, 0, 0), 2)
paintWindow = cv2.rectangle(paintWindow, (275, 1), (370, 65), (0, 255, 0), 2)
paintWindow = cv2.rectangle(paintWindow, (390, 1), (485, 65), (0, 0, 255), 2)
paintWindow = cv2.rectangle(paintWindow, (505, 1), (600, 65), (0, 255, 255), 2)

#boxes mebackground color fill karne ke liye -1
cv2.rectangle(paintWindow, (505, 1), (600, 65), (255, 255, 0), -1)
cv2.rectangle(paintWindow, (160, 1), (255, 65), (255, 0, 0), -1)  # Blue
cv2.rectangle(paintWindow, (275, 1), (370, 65), (0, 255, 0), -1)  # Green
cv2.rectangle(paintWindow, (390, 1), (485, 65), (0, 0, 255), -1)  # Red
cv2.rectangle(paintWindow, (505, 1), (600, 65), (0, 255, 255), -1)  # Yellow

#text color
cv2.putText(paintWindow, "CLEAR", (49, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
cv2.putText(paintWindow, "BLUE", (185, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
cv2.putText(paintWindow, "GREEN", (298, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
cv2.putText(paintWindow, "RED", (420, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
cv2.putText(paintWindow, "YELLOW", (520, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)



mpHands = mp.solutions.hands
hands = mpHands.Hands(max_num_hands=4, min_detection_confidence=0.9)
mpDraw = mp.solutions.drawing_utils

# Define custom drawing styles
hand_landmark_style = mpDraw.DrawingSpec(color=(117,117,117), thickness=5)  # Green color for landmarks
hand_connection_style = mpDraw.DrawingSpec(color=(255, 255, 255), thickness=2)  # Red color for connections


cap = cv2.VideoCapture(0)
ret = True
while ret:
    
    ret, frame = cap.read()

    x, y, c = frame.shape

    # Flip the frame vertically
    frame = cv2.flip(frame, 1)
    
    framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    frame = cv2.rectangle(frame, (40, 1), (140, 65), (0, 0, 0), 2)
    frame = cv2.rectangle(frame, (160, 1), (255, 65), (255, 0, 0), 2)
    frame = cv2.rectangle(frame, (275, 1), (370, 65), (0, 255, 0), 2)
    frame = cv2.rectangle(frame, (390, 1), (485, 65), (0, 0, 255), 2)
    frame = cv2.rectangle(frame, (505, 1), (600, 65), (0, 255, 255), 2)
    cv2.putText(frame, "CLEAR", (49, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, "BLUE", (185, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, "GREEN", (298, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, "RED", (420, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, "YELLOW", (520, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
    

    
    result = hands.process(framergb)

    
    if result.multi_hand_landmarks:
        landmarks = []
        for handslms in result.multi_hand_landmarks:
            for lm in handslms.landmark:
               
                lmx = int(lm.x * 640)
                lmy = int(lm.y * 480)

                landmarks.append([lmx, lmy])

            
            mpDraw.draw_landmarks(frame, handslms, mpHands.HAND_CONNECTIONS,hand_landmark_style,hand_connection_style)
        fore_finger = (landmarks[8][0], landmarks[8][1])
        center = fore_finger
        thumb = (landmarks[4][0], landmarks[4][1])
        #cv2.circle(frame,  center, 10, (25, 25, 2456), -1)
        
        print(center[1] - thumb[1])
        if (thumb[1] - center[1] < 30):
            bpoints.append(deque(maxlen=512))
            blue_index += 1
            gpoints.append(deque(maxlen=512))
            green_index += 1
            rpoints.append(deque(maxlen=512))
            red_index += 1
            ypoints.append(deque(maxlen=512))
            yellow_index += 1

        elif center[1] <= 65:
            if 40 <= center[0] <= 140:  # Clear Button
                frame = cv2.rectangle(frame, (40, 1), (140, 65), (255, 255, 255), -1)
                cv2.putText(frame, "CLEAR", (49, 33), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
                cv2.circle(frame, center, 3, (255, 255, 255), -1)
                
                bpoints = [deque(maxlen=512)]
                gpoints = [deque(maxlen=512)]
                rpoints = [deque(maxlen=512)]
                ypoints = [deque(maxlen=512)]

                blue_index = 0
                green_index = 0
                red_index = 0
                yellow_index = 0

                paintWindow[67:, :, :] = 255
            elif 160 <= center[0] <= 255:
                colorIndex = 0  # Blue
                cv2.circle(frame, center, 3, (255, 0, 0), -1)
            elif 275 <= center[0] <= 370:
                colorIndex = 1  # Green
                cv2.circle(frame, center, 3, (0, 255, 0), -1)
            elif 390 <= center[0] <= 485:
                colorIndex = 2  # Red
                cv2.circle(frame, center, 3, (0, 0, 255), -1)
            elif 505 <= center[0] <= 600:
                colorIndex = 3  # Yellow
                cv2.circle(frame, center, 3, (0, 255, 255), -1)
        else:
            if colorIndex == 0:
                bpoints[blue_index].appendleft(center)
                cv2.circle(frame, center, 3, (255, 0, 0), -1)
            elif colorIndex == 1:
                gpoints[green_index].appendleft(center)
                cv2.circle(frame, center, 3, (0, 255, 0), -1)
            elif colorIndex == 2:
                rpoints[red_index].appendleft(center)
                cv2.circle(frame, center, 3, (0, 0, 255), -1)
            elif colorIndex == 3:
                ypoints[yellow_index].appendleft(center)
                cv2.circle(frame, center, 3, (0, 255, 255), -1)
    
    else:
        bpoints.append(deque(maxlen=512))
        blue_index += 1
        gpoints.append(deque(maxlen=512))
        green_index += 1
        rpoints.append(deque(maxlen=512))
        red_index += 1
        ypoints.append(deque(maxlen=512))
        yellow_index += 1

    # Draw lines of all the colors on the canvas and frame
    points = [bpoints, gpoints, rpoints, ypoints]   #list
    #code to draw on canva
    for i in range(len(points)):
        for j in range(len(points[i])):
            for k in range(1, len(points[i][j])):
                if points[i][j][k - 1] is None or points[i][j][k] is None:   #mtlb draw nhi kiya hua hai ya frame se bahar chala gaya
                    continue
                cv2.line(frame, points[i][j][k - 1], points[i][j][k], colors[i], 2) #yeh canvas me draw karega
                cv2.line(paintWindow, points[i][j][k - 1], points[i][j][k], colors[i], 2) # yeh paintwindow me

    cv2.imshow("Output", frame)
    cv2.imshow("Paint", paintWindow)

    if cv2.waitKey(1) == ord('q'):
        break

# release the webcam and destroy all active windows
cap.release()
cv2.destroyAllWindows()
# Out:
# -107
# -109
# -118
# -127
# C:\Users\shrey\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# -125
# -124
# -131
# -129
# -133
# -133
# -132
# -131
# -130
# -130
# -128
# -127
# -128
# -128
# -127
# -126
# -127
# -128
# -126
# -126
# -127
# -127
# -131
# -126
# -125
# -125
# -131
# -131
# -131
# -132
# -132
# -132
# -131
# -131
# -131
# -131
# -131
# -131
# -132
# -132
# -133
# -132
# -131
# -132
# -131
# -131
# -131
# -132
# -132
# -131
# -131
# -131
# -131
# -131
# -131
# -131
# -131
# -131
# -131
# -131
# -132
# -131
# -132
# -133
# -133
# -133
# -133
# -131
# -132
# -132
# -132
# -132
# -132
# -132
# -132
# -131
# -131
# -132
# -131
# ...

# %%
import cv2
import mediapipe as mp
import numpy as np 
mphand=mp.solutions.hands
hand=mphand.Hands()

mpDraw=mp.solutions.drawing_utils

#mp_drawing = mp.solutions.drawing_utils

# Define custom drawing styles
hand_landmark_style = mpDraw.DrawingSpec(color=(117,117,117), thickness=5)  # Green color for landmarks
hand_connection_style = mpDraw.DrawingSpec(color=(255, 255, 255), thickness=2)  # Red color for connections

cap=cv2.VideoCapture(0)

while True:
    sucess,img=cap.read()

    imgrgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    result=hand.process(imgrgb)
   # print(result.multi_hand_landmarks)
    if result.multi_hand_landmarks:
        for handlm in result.multi_hand_landmarks:
                   
            for id,lm in enumerate(handlm.landmark):
                #print(id,lm) 
                h,w,c=img.shape
                cx,cy=int(lm.x*w),int(lm.y*h)
                print(id,cx,cy)

            mpDraw.draw_landmarks(img,handlm,mphand.HAND_CONNECTIONS,  hand_landmark_style,
                    hand_connection_style)
    cv2.imshow("Vedio",img)
    cv2.waitKey(1)

    if cv2.waitKey(1) == ord('q'):
        break
q
